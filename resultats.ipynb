# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
col_names = ["k=2","k=3","k=4","k=5","k=6"]
index_names = ["N=0","N=25.000","N=50.000","N=75.000","N=100.000","N=125.000","N=150.000",
              "N=175.000","N=200.000","N=225.000","N=250.000"]
dades = [
[25,44,81,175,311],
[28,52,89,182,351],
[28,47,100,212,409],
[29,49,107,208,403],
[30,52,107,239,419],
[31,53,116,222,407],
[30,59,107,228,525],
[29,61,111,230,485],
[31,55,113,240,527],
[32,59,116,258,470],
[31,56,122,270,473],
[31,59,121,265,529],
[31,57,112,259,531],
[32,64,115,260,572],
[33,55,125,251,534],
[33,62,117,247,581],
[33,62,138,249,528],
[32,60,118,274,566],
[33,60,121,274,619],
[34,66,127,258,568],
[31,56,122,276,607],
[33,59,139,301,575],
[33,59,129,272,618],
[34,60,131,265,544],
[34,66,122,312,573],
[33,64,140,288,646],
[34,60,136,270,561],
[32,61,133,293,637],
[35,70,117,296,699],
[33,59,127,312,614],
[33,62,128,322,671],
[34,64,125,279,617],
[34,62,137,282,590],
[35,64,133,292,570],
[34,63,137,278,623],
[34,56,145,280,579],
[34,61,131,325,662],
[36,62,133,305,662],
[34,60,132,284,668],
[33,71,121,288,746],
[33,61,140,311,663],
[33,64,141,283,615],
[35,65,129,300,660],
[34,60,145,307,620],
[35,70,153,329,722],
[36,62,129,284,645],
[35,67,149,286,670],
[35,68,138,277,625],
[36,62,141,339,731],
[34,63,134,306,714]]


df_standard = pd.DataFrame(dades, columns = col_names)
df_standard
# Out:
#     k=2  k=3  k=4  k=5  k=6
# 0    25   44   81  175  311
# 1    28   52   89  182  351
# 2    28   47  100  212  409
# 3    29   49  107  208  403
# 4    30   52  107  239  419
# 5    31   53  116  222  407
# 6    30   59  107  228  525
# 7    29   61  111  230  485
# 8    31   55  113  240  527
# 9    32   59  116  258  470
# 10   31   56  122  270  473
# 11   31   59  121  265  529
# 12   31   57  112  259  531
# 13   32   64  115  260  572
# 14   33   55  125  251  534
# 15   33   62  117  247  581
# 16   33   62  138  249  528
# 17   32   60  118  274  566
# 18   33   60  121  274  619
# 19   34   66  127  258  568
# 20   31   56  122  276  607
# 21   33   59  139  301  575
# 22   33   59  129  272  618
# 23   34   60  131  265  544
# 24   34   66  122  312  573
# 25   33   64  140  288  646
# 26   34   60  136  270  561
# 27   32   61  133  293  637
# 28   35   70  117  296  699
# 29   33   59  127  312  614
# 30   33   62  128  322  671
# 31   34   64  125  279  617
# ...

# %%
dades_estandard0_100 = [
[22,39,82,145,226],
[23,43,84,154,280],
[26,47,88,177,307],
[27,52,93,183,358],
[27,51,101,188,385],
[27,52,92,170,411],
[27,51,104,198,439],
[28,50,108,211,385],
[27,47,106,234,424],
[28,55,101,226,412],
[28,54,106,234,434],
[30,55,115,228,444],
[29,57,102,239,414],
[30,52,109,232,471],
[30,51,122,244,455],
[29,55,114,252,449],
[29,52,118,229,470],
[30,55,114,236,477],
[31,58,121,235,428],
[30,59,124,229,480],
[30,50,119,247,503],
[29,55,122,244,560],
[31,55,119,235,520],
[29,55,110,238,507],
[32,58,116,268,552],
[30,57,114,268,547],
[31,55,112,239,503],
[31,55,115,240,538],
[31,59,114,254,568],
[29,59,112,264,513],
[31,59,136,259,558],
[31,64,121,241,560],
[32,63,126,251,539],
[32,56,124,280,549],
[32,58,117,256,632],
[33,59,117,266,537],
[33,63,121,270,591],
[31,62,124,283,604],
[30,60,125,246,571],
[31,59,125,263,539],
[32,55,119,267,558],
[34,60,132,258,583],
[33,59,132,267,577],
[32,61,131,280,574],
[32,57,119,282,586],
[33,62,128,275,564],
[32,62,126,244,619],
[32,65,112,280,544],
[34,62,133,256,604],
[33,60,131,290,667]]

index_names = ["N=0","N=10000","N=20.000","N=30.000","N=40.000","N=50.000","N=60.000","N=70.000",
              "N=80.000","N=90.000","N=100.000"]

df_standard = pd.DataFrame(dades_estandard0_100, columns = col_names)

# %%
fig = plt.figure(figsize=(4,2),dpi=200)

axes = fig.add_axes([0,0,1,1])
axes.plot(df_standard["k=2"],label="k=2",linestyle="-")
axes.plot(df_standard["k=3"],label="k=3",linestyle="-")
axes.plot(df_standard["k=4"],label="k=4",linestyle="-")
axes.plot(df_standard["k=5"],label="k=5",linestyle="-")
axes.plot(df_standard["k=6"],label="k=6",linestyle="-")

axes.tick_params(axis='both', labelsize=4)

plt.title("k-d Standard Binary-Tree")

plt.xlabel("# nodes de l'arbre",fontsize=10)
plt.ylabel("# nodes consultats durant la cerca", fontsize=10)
plt.legend()

axes.set_xticks([0,5,10,15,20,25,30,35,40,45,50])
axes.set_xticklabels(index_names)

legend = axes.legend()
legend.

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 22
#      19 axes.set_xticklabels(index_names)
#      21 legend = axes.legend()
# ---> 22 legend.set_fontsize(8)
#      24 plt.show()
#
# AttributeError: 'Legend' object has no attribute 'set_fontsize'
